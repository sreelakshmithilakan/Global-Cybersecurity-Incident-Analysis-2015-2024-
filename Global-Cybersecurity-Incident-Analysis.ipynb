# %% [markdown]
# # **Global Cybersecurity Incident Analysis (2015–2024)**
# >*Exploring Geographical, Industrial, Operational, and Temporal Risk Patterns*
#
# <hr>
#
#
#
# ## **Problem Statement**
#
# Cyber-attacks have grown significantly in scale and complexity, causing major financial and operational damage across industries. This project analyzes global cybersecurity incidents from **2015–2024** to identify key trends, relationships, and risk factors influencing **financial loss**, **number of affected users**, and **incident resolution times**.
#
# ---
#
# ## **Project Relevance**
#
# - Cybersecurity is one of the fastest-growing domains within the field of Information Technology.
# - The dataset integrates both categorical and numerical variables, enabling diverse analytical techniques.
# - The project demonstrates skills in Python-based data cleaning, visualization, and insight generation, relevant for data-driven cybersecurity decision-making.
#
#
# <hr>
#
# ## **1. Dataset Overview**
#
# ### **Initial Columns**
#
# - `Country` – Country where the attack occurred
# - `Year` – Year of the cybersecurity incident
# - `Attack Type` – Type of cybersecurity attack (e.g., Malware, DDoS)
# - `Target Industry` – Industry targeted by the attack (e.g., Finance, Healthcare)
# - `Financial Loss (in Million $)` – Estimated financial loss in millions of dollars
# - `Number of Affected Users` – Number of users impacted by the incident
# - `Attack Source` – Source of attack (e.g., Internal, External)
# - `Security Vulnerability Type` – Type of vulnerability exploited
# - `Defense Mechanism Used` – Defense or mitigation strategy implemented
# - `Incident Resolution Time (in Hours)` – Total hours taken to mitigate the incident
#
# ---
#
# ### **Derived Columns**
#
# - `Era` → *'Pre-Pandemic', 'Pandemic (2020–2021)', 'Recovery (2022–2023)', 'Recent (2024–2025)'*
# - `Resolution Bucket` → *Categorized resolution time (0–24h,24–48h,<= 48,48–72h,<= 72,>72h)*
# - `Loss per User` → *Loss per Incident ÷ Number of Affected Users*
#
# <hr>
#
# ## **2. Key Analytical Questions**
#
# ### **1. Geographical & Industrial Impact**
# - *Which countries and industries experience the highest financial losses and largest user impact?*
# - *Which countries show improving cybersecurity outcomes over time (lower losses, faster resolution, or fewer incidents)?*
#
#
# ### **2. Attack Typology & Vulnerabilities**
# - *Which attack types are most prevalent, and which vulnerabilities do they commonly exploit across industries?*
#
#
# ### **3. Financial & Operational Relationships**
# - *How are financial loss, number of affected users, and resolution time related?*
# - *Which types of incidents show a higher risk of escalation (high loss or long resolution time)?*
#
#
# ### **4. Defense Effectiveness**
# - *Which defense mechanisms are most effective in reducing loss, downtime, and user impact?*
# - *How has the adoption and effectiveness of defense mechanisms evolved over time?*
#
#
# ### **5. Temporal Evolution & Emerging Trends**
# - *How have cyber threats evolved over time in terms of type, impact, and frequency?*
# - *What significant changes can be observed in threat patterns and impacts post-2020?*
#
#
# ## **3. Data Cleaning and Preprocessing**
#
# **Objective:** *Ensure data consistency and integrity before analysis.*
#
# **Steps:**
# - Handle missing values (`Financial Loss`, `Incident Resolution Time`, `Attack Type`, etc.)
# - Remove duplicates and standardize categorical entries (e.g., country names, industry labels)
# - Convert columns to appropriate data types
# - Create derived fields:
#   - *Era* (Pre vs Post-Pandemic)
#   - *Loss per Incident*
#   - *Resolution Bucket* (≤24h, 24–72h, >72h)
# - Detect and handle outliers
#
# ---
#
# ## **4. Descriptive and Summary Statistics**
#
# **Objective:** *Obtain a general overview of the dataset.*
#
# **Steps:**
# - Compute **mean**, **median**, **min**, **max**, **standard deviation** for numerical variables
# - Basic pivot tables:
#   - Total Financial Loss by Country
#   - Total Users by Industry
# - Identify trends over time (Year-wise incident count)
#
# ---
#
# ## **5. Univariate Analysis**
#
# **Purpose:** *Understand the distribution and frequency of single variables.*
#
# **Related Questions:**
# - “Which countries/industries suffer the highest losses and largest user impact?”
# - “Which attacks dominate globally?”
# - “How have threats shifted over time?”
#
# **Key Variables & Plots:**
#
# | Variable | Plot Type | Purpose |
# |----------|-----------|---------|
# | Country | Bar Chart | Frequency of incidents |
# | Attack Type | Pie Chart | Most common attack types |
# | Target Industry | Horizontal Bar | Targeted sectors |
# | Incident Resolution Time | KDE | Incident duration |
# | Era (Pre vs Post) | Bar Chart | Incident count comparison |
#
# ---
#
# ## **6. Bivariate Analysis**
#
# **Purpose:** *Explore relationships between pairs of variables.*
#
# **Related Questions:**
# - Q1: Geographical & Industrial Impact
# - Q2: Attack Typology & Vulnerabilities
# - Q3: Financial & Operational Relationships
# - Q4: Defense Effectiveness
# - Q5: Temporal Trends
#
# | Relationship | Plot Type | Question Addressed |
# |--------------|-----------|---------------------|
# | Country × Financial Loss | Bar Plot | Q1: High loss regions |
# | Target Industry × Users | Horizontal Bar | Q1: User impact by sector |
# | Attack Type × Industry | % Stacked Bar | Q2: Dominant threats |
# | Defense Mechanism × Resolution Time | Violin | Q4: Defense effectiveness |
#
# ---
#
# ## **7. Multivariate Analysis**
#
# **Purpose:** *Examine interactions among multiple variables to detect deeper patterns.*
#
# **Related Questions:** Q1, Q2, Q3, Q4, Q5
#
# | Relationship | Plot Type | Question Addressed |
# |--------------|-----------|---------------------|
# | Users × Industry × Year | Heatmap / Line | Q1: Evolution of user impact |
# | Attack Type × Vulnerability × Defense | Grouped Bar Plot| Q2, Q4: Attack–exploit–defense |
# | Pre vs Post-Pandemic × Attack Type | Side-by-side Bars | Q5: Threat evolution |
# | Attack Source × Industry × Country | Bubble plot| Q5: Global threat landscape |
#
# ---
#
# ## **8. Correlation and Statistical Analysis**
#
# **Purpose:** *Quantify relationships between numeric features.*
#
# **Related Questions:** Q3: Financial & Operational Relationships
#
# **Focus Areas:**
# - Correlation matrix:
#   - `Financial Loss (in Million $)`
#   - `Number of Affected Users`
#   - `Incident Resolution Time (in Hours)`
#
# ---
#
# ## **9. Temporal and Trend Analysis**
#
# **Purpose:** *Understand how threats and defenses have evolved from 2015 to 2024.*
#
# **Related Questions:** Q1, Q2, Q5
#
# | Relationship | Plot Type | Question Addressed |
# |--------------|-----------|---------------------|
# | Year × Attack Type | 100% Stacked Area Chart | Q2: Attack Landscape |
# | Year × Avg Financial Loss (by Defense Mechanism)| Multi-series Line Chart| Q5: Defense over Time |
# | Year ×  (Loss & Users) | Dual-axis Line | Q1: Loss of Users |
#
# ---
#
# ## **10. Insight Extraction and Interpretation**
#
# **Purpose:** *Translate findings into actionable conclusions.*
#
# **Linked Questions:** All five
#
# - High-risk countries and industries over time
# - Attack types and vulnerabilities driving highest losses
# - Incidents with high individual severity, not just total financial damage
# - Defense strategies that consistently reduce resolution time and loss
# - Temporal shifts in threats post-2020
# - Relationship between operational delays and financial damage
#
# ---
# ## **11. Limitations & Future Scope**
# **Purpose:** *Acknowledging current analytical boundaries and highlighting directions for future enhancement.*
#   - Limitations
#   - Future Scopes

# %% [markdown]
# <br>
# <br>
#
#
# ## **1. Data Cleaning and Preprocessing:**
# >***Objective:*** *Ensure data consistency and integrity before analysis.*

# %%
import pandas as pd
df = pd.read_csv('Global_Cybersecurity_Threats.csv')
print('First 10 rows of the data:\n')
df.head(10)
# Out:
# First 10 rows of the data:
#    Country  Year        Attack Type     Target Industry  \
# 0    China  2019           Phishing           Education
# 1    China  2019         Ransomware              Retail
# 2    India  2017  Man-in-the-Middle                  IT
# 3       UK  2024         Ransomware  Telecommunications
# 4  Germany  2018  Man-in-the-Middle                  IT
# 5  Germany  2017  Man-in-the-Middle              Retail
# 6  Germany  2016               DDoS  Telecommunications
# 7   France  2018      SQL Injection          Government
# 8    India  2016  Man-in-the-Middle             Banking
# 9       UK  2023               DDoS          Healthcare
#
#    Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 0                          80.53                    773169  Hacker Group
# 1                          62.19                    295961  Hacker Group
# 2                          38.65                    605895  Hacker Group
# ...

# %%
print('Last 10 rows of the data:\n')
df.tail(10)
# Out:
# Last 10 rows of the data:
#       Country  Year    Attack Type     Target Industry  \
# 2990   France  2015       Phishing  Telecommunications
# 2991   Russia  2019     Ransomware             Banking
# 2992       UK  2021        Malware             Banking
# 2993  Germany  2017  SQL Injection           Education
# 2994  Germany  2019     Ransomware          Government
# 2995       UK  2021     Ransomware          Government
# 2996   Brazil  2023  SQL Injection  Telecommunications
# 2997   Brazil  2017  SQL Injection                  IT
# 2998       UK  2022  SQL Injection                  IT
# 2999  Germany  2021  SQL Injection              Retail
#
#       Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 2990                          65.16                    998011       Unknown
# 2991                          28.14                    594170  Nation-state
# 2992                          60.14                    191427  Nation-state
# ...

# %%
print('Shape of the DataFrame:')
df.shape
# Out:
# Shape of the DataFrame:
# (3000, 10)

# %%
print("Columns of the dataset: \n \n", df.columns)
# Out:
# Columns of the dataset:
#
#  Index(['Country', 'Year', 'Attack Type', 'Target Industry',
#        'Financial Loss (in Million $)', 'Number of Affected Users',
#        'Attack Source', 'Security Vulnerability Type',
#        'Defense Mechanism Used', 'Incident Resolution Time (in Hours)'],
#       dtype='object')

# %%
print("Number of unique values in each columns: \n \n",  df.nunique())
# Out:
# Number of unique values in each columns:
#
#  Country                                  10
# Year                                     10
# Attack Type                               6
# Target Industry                           7
# Financial Loss (in Million $)          2536
# Number of Affected Users               2998
# Attack Source                             4
# Security Vulnerability Type               4
# Defense Mechanism Used                    5
# Incident Resolution Time (in Hours)      72
# dtype: int64

# %%
print("Categories/Unique values in each columns: \n \n",  
      
      'Year:', df['Year'].unique(), 
      '\n \n Attack Type',df['Attack Type'].unique(),
      '\n \n Target Industry',df['Target Industry'].unique(),
      '\n \n Target Industry',df['Target Industry'].unique(),
      '\n \n Attack Source',df['Attack Source'].unique(),
      '\n \n Defense Mechanism Used',df['Defense Mechanism Used'].unique(),
      
      )
# Out:
# Categories/Unique values in each columns:
#
#  Year: [2019 2017 2024 2018 2016 2023 2022 2015 2021 2020]
#
#  Attack Type ['Phishing' 'Ransomware' 'Man-in-the-Middle' 'DDoS' 'SQL Injection'
#  'Malware']
#
#  Target Industry ['Education' 'Retail' 'IT' 'Telecommunications' 'Government' 'Banking'
#  'Healthcare']
#
#  Target Industry ['Education' 'Retail' 'IT' 'Telecommunications' 'Government' 'Banking'
#  'Healthcare']
#
#  Attack Source ['Hacker Group' 'Nation-state' 'Insider' 'Unknown']
#
#  Defense Mechanism Used ['VPN' 'Firewall' 'AI-based Detection' 'Antivirus' 'Encryption']

# %%
print("Number of null values in each column: \n \n", df.isnull().sum())
# Out:
# Number of null values in each column:
#
#  Country                                0
# Year                                   0
# Attack Type                            0
# Target Industry                        0
# Financial Loss (in Million $)          0
# Number of Affected Users               0
# Attack Source                          0
# Security Vulnerability Type            0
# Defense Mechanism Used                 0
# Incident Resolution Time (in Hours)    0
# dtype: int64

# %% [markdown]
# No null values detected

# %%
print("Total number of duplicates: \n \n", df.duplicated().sum())
# Out:
# Total number of duplicates:
#
#  0

# %% [markdown]
# - No duplicates detected and there are no inconsistent entries.
# - Categorical data, numerical data, and column headers are in standard condition.

# %%
print('Non-null counts and data types in each column:\n')
df.info()
# Out:
# Non-null counts and data types in each column:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              3000 non-null   object
#  1   Year                                 3000 non-null   int64
#  2   Attack Type                          3000 non-null   object
#  3   Target Industry                      3000 non-null   object
#  4   Financial Loss (in Million $)        3000 non-null   float64
#  5   Number of Affected Users             3000 non-null   int64
#  6   Attack Source                        3000 non-null   object
#  7   Security Vulnerability Type          3000 non-null   object
#  8   Defense Mechanism Used               3000 non-null   object
#  9   Incident Resolution Time (in Hours)  3000 non-null   int64
# ...

# %% [markdown]
# ### _Creating derived fields:_

# %%
import numpy as np

# Column names
YEAR_COL = "Year"
LOSS_COL = "Financial Loss (in Million $)"
USERS_COL = "Number of Affected Users"
RES_HR_COL = "Incident Resolution Time (in Hours)"

# 1) Era: Pre vs Post-Pandemic (cut at 2020)

df['Era'] = None
df.loc[df['Year'] <= 2019, 'Era'] = 'Pre-Pandemic'
df.loc[(df['Year'] > 2019) & (df['Year'] <= 2021), 'Era'] = 'Pandemic (2020–2021)'
df.loc[(df['Year'] > 2021) & (df['Year'] <= 2023), 'Era'] = 'Recovery (2022–2023)'
df.loc[df['Year'] > 2023, 'Era'] = 'Recent (2024–2025)'

df['Era'] = df['Era'].astype('category')
print(df['Era'].value_counts(normalize=True) * 100)
print('_______________________________________________________________________________________________')

# 2) Loss per User ($) — avoid divide by zero

df["Loss per User ($)"] = ((df[LOSS_COL] * 1_000_000) / df[USERS_COL]).round(2) 
print(df["Loss per User ($)"].value_counts(normalize=True) * 100)
print('_______________________________________________________________________________________________')

# 3) Resolution Bucket — categorize resolution time

df['Resolution Bucket'] = df['Incident Resolution Time (in Hours)'].apply(
    lambda x: '0–24h' if x <= 24 else
              '24–48h' if x <= 48 else
              '48–72h' if x <= 72 else
              '>72h'
).astype('category')
print(df['Resolution Bucket'].value_counts(normalize=True) * 100)
print('_______________________________________________________________________________________________')


print(df[["Era", "Loss per User ($)", "Resolution Bucket"]].head())
# Out:
# Era
# Pre-Pandemic            48.466667
# Recovery (2022–2023)    21.100000
# Pandemic (2020–2021)    20.466667
# Recent (2024–2025)       9.966667
# Name: proportion, dtype: float64
# _______________________________________________________________________________________________
# Loss per User ($)
# 91.79      0.133333
# 94.65      0.100000
# 19.19      0.100000
# 82.46      0.100000
# 99.01      0.100000
#              ...
# 197.81     0.033333
# 525.38     0.033333
# 22.06      0.033333
# 4967.21    0.033333
# 344.46     0.033333
# Name: proportion, Length: 2838, dtype: float64
# _______________________________________________________________________________________________
# Resolution Bucket
# 24–48h    34.200000
# 0–24h     33.033333
# 48–72h    32.766667
# Name: proportion, dtype: float64
# _______________________________________________________________________________________________
#                   Era  Loss per User ($) Resolution Bucket
# ...

# %% [markdown]
# ### _Finding outliers using Interquartile Range Method:_

# %%
print('Finding outliers using Interquartile Range Method:')
print('_______________________________________________________________________________________________')

num_cols = ['Financial Loss (in Million $)','Number of Affected Users','Incident Resolution Time (in Hours)','Loss per User ($)']

outlier_summary = {}

for col in num_cols:

    df[col] = pd.to_numeric(df[col], errors='coerce')


    col_min = df[col].min()
    col_max = df[col].max()
    col_range = col_max - col_min


    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    count = len(outliers)

    outlier_summary[col] = {
        "min": col_min,
        "max": col_max,
        "range": col_range,
        "IQR": IQR,
        "lower_bound": lower_bound,
        "upper_bound": upper_bound,
        "outliers_count": count
    }


for col, stats in outlier_summary.items():
    print(f"\n Column: {col}")
    print(f"   Min = {stats['min']}")
    print(f"   Max = {stats['max']}")
    print(f"   Range = {stats['range']}")
    print(f"   IQR = {stats['IQR']:.2f}")
    print(f"   Lower Bound = {stats['lower_bound']:.2f}")
    print(f"   Upper Bound = {stats['upper_bound']:.2f}")
    print(f"   Outliers Count = {stats['outliers_count']}")

print('''\nFor 'Loss per User ($)' 338 outliers are detected.
      
Here IQR is very small compared to your max. A majority of incidents probably involve low per-user losses (0–300 USD range). 

But a small number of incidents had very large losses per user (hundreds to thousands).

This stretches your range but doesn’t affect Q1 and Q3 much — they stay low, so the upper bound remains small → lots of outliers.

Conclusion: Thus the distribution is right-skewed (long tail on the higher side). A small percent of incidents are very costly per user.''')
# Out:
# Finding outliers using Interquartile Range Method:
# _______________________________________________________________________________________________
#
#  Column: Financial Loss (in Million $)
#    Min = 0.5
#    Max = 99.99
#    Range = 99.49
#    IQR = 49.87
#    Lower Bound = -49.05
#    Upper Bound = 150.44
#    Outliers Count = 0
#
#  Column: Number of Affected Users
#    Min = 424
#    Max = 999635
#    Range = 999211
#    IQR = 502283.25
#    Lower Bound = -497619.62
#    Upper Bound = 1511513.38
#    Outliers Count = 0
#
#  Column: Incident Resolution Time (in Hours)
#    Min = 1
#    Max = 72
#    Range = 71
#    IQR = 36.00
#    Lower Bound = -35.00
#    Upper Bound = 109.00
#    Outliers Count = 0
#
#  Column: Loss per User ($)
#    Min = 0.62
#    Max = 141058.02
#    Range = 141057.4
#    IQR = 153.04
#    Lower Bound = -179.69
#    Upper Bound = 432.45
#    Outliers Count = 338
#
# For 'Loss per User ($)' 338 outliers are detected.
#
# ...

# %% [markdown]
# ---
#
# ## **3. Descriptive and Summary Statistics:**
# > *Obtain a general overview of the dataset.*

# %% [markdown]
# ### _Summary statistics of all data:_

# %%
print('Summary statistics of all data: \n')
df.describe(include='all')
# Out:
# Summary statistics of all data:
#        Country         Year Attack Type Target Industry  \
# count     3000  3000.000000        3000            3000
# unique      10          NaN           6               7
# top         UK          NaN        DDoS              IT
# freq       321          NaN         531             478
# mean       NaN  2019.570333         NaN             NaN
# std        NaN     2.857932         NaN             NaN
# min        NaN  2015.000000         NaN             NaN
# 25%        NaN  2017.000000         NaN             NaN
# 50%        NaN  2020.000000         NaN             NaN
# 75%        NaN  2022.000000         NaN             NaN
# max        NaN  2024.000000         NaN             NaN
#
#         Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# count                     3000.000000               3000.000000          3000
# unique                            NaN                       NaN             4
# ...

# %% [markdown]
# ### _Variability, Skewness & Standard Deviation of data:_

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

print("Variability, Skewness & Standard Deviation in Data\n")
print("=====================================================================================")

for col in num_cols:
    print(f"\n Column: {col}")
    print("-" * (len(col) + 12))
    
    #Variability 
    col_min = df[col].min()
    col_max = df[col].max()
    minmax_diff = col_max - col_min
    print(f"Range (Max - Min): {minmax_diff:.2f}")
    
    if minmax_diff > df[col].median() * 2:
        print("Conclusion: High variability — wide spread in data.")
    else:
        print("Conclusion: Low variability — values are close together.")
    
    #Skewness 
    mean_val = df[col].mean()
    median_val = df[col].median()
    skewness = mean_val - median_val
    skew_type = df[col].skew()
    print(f"\nMean - Median = {skewness:.2f}")
    print(f"Skewness value = {skew_type:.2f}")
    
    if skew_type > 0.5:
        print("Conclusion: Right (positively) skewed distribution.")
    elif skew_type < -0.5:
        print("Conclusion: Left (negatively) skewed distribution.")
    else:
        print("Conclusion: Roughly symmetric distribution.")
    
    #Standard Deviation
    std_dev = df[col].std()
    print(f"\nStandard Deviation = {std_dev:.2f}")
    
    cv = (std_dev / mean_val) * 100 if mean_val != 0 else np.nan
    if cv > 100:
        print("Conclusion: Very high variability relative to mean.")
    elif cv > 50:
        print("Conclusion: Moderately variable data.")
    else:
        print("Conclusion: Data is fairly consistent.")
    
    print("\n" + "-"*80)
# Out:
# Variability, Skewness & Standard Deviation in Data
#
# ...
#
#  Column: Year
# ----------------
# Range (Max - Min): 9.00
# Conclusion: Low variability — values are close together.
#
# Mean - Median = -0.43
# Skewness value = -0.03
# Conclusion: Roughly symmetric distribution.
#
# Standard Deviation = 2.86
# Conclusion: Data is fairly consistent.
#
# --------------------------------------------------------------------------------
#
#  Column: Financial Loss (in Million $)
# -----------------------------------------
# Range (Max - Min): 99.49
# Conclusion: Low variability — values are close together.
#
# Mean - Median = -0.30
# Skewness value = -0.02
# Conclusion: Roughly symmetric distribution.
#
# Standard Deviation = 28.79
# Conclusion: Moderately variable data.
#
# --------------------------------------------------------------------------------
#
#  Column: Number of Affected Users
# ------------------------------------
# Range (Max - Min): 999211.00
# ...

# %% [markdown]
#  ### _Basic pivot tables:_

# %%
print('Total Financial Loss by Country:\n')
pivot_loss_country = df.pivot_table(
    index='Country',
    values='Financial Loss (in Million $)',
    aggfunc='sum'
).sort_values(by='Financial Loss (in Million $)', ascending=False)

print(pivot_loss_country.head())
# Out:
# Total Financial Loss by Country:
#
#            Financial Loss (in Million $)
# Country
# UK                              16502.99
# Germany                         15793.24
# Brazil                          15782.62
# Australia                       15403.00
# Japan                           15197.34

# %%
print('Total Users by Industry:\n')
pivot_users_industry = df.pivot_table(
    index='Target Industry',
    values='Number of Affected Users',
    aggfunc='sum'
).sort_values(by='Number of Affected Users', ascending=False)

print(pivot_users_industry.head())
# Out:
# Total Users by Industry:
#
#                  Number of Affected Users
# Target Industry
# IT                              250094829
# Banking                         225098406
# Healthcare                      216271916
# Education                       215004732
# Retail                          206776386

# %% [markdown]
# ### _Identify trends over time (Year-wise incident count):_

# %%
# Year-wise incident count
yearly_incidents = df.groupby('Year').size().reset_index(name='Incident Count')
print(yearly_incidents)
# Out:
#    Year  Incident Count
# 0  2015             277
# 1  2016             285
# 2  2017             319
# 3  2018             310
# 4  2019             263
# 5  2020             315
# 6  2021             299
# 7  2022             318
# 8  2023             315
# 9  2024             299

# %% [markdown]
# ---
#
# ### **Univariate Analysis:**
#
# >***Purpose:*** *Understand the distribution and frequency of single variables.*
#
# **Related Questions:**
# - “Which countries/industries suffer the highest losses and largest user impact?”
# - “Which attacks dominate globally?”
# - “How have threats shifted over time?”

# %% [markdown]
# __Distribution of Cyber Incidents by Country | Bar Plot__

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cool_colors = ["#003f5c","#2f4b7c","#665191","#a05195","#d45087","#f95d6a","#ff7c43","#ffa600","#00bfae","#4db6ac"]
df['Country'].value_counts().plot(kind='bar',figsize=(10,5),color=cool_colors)
plt.title('Distribution of Cyber Incidents by Country', fontsize=13, weight='bold')
plt.xlabel('Country')
plt.ylabel('Count')
plt.grid(True,linestyle='--')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - Most cases reported in UK, Brazil, Japan and France, ie., greater than 300.
# - Rest of the countries have lessser incidents reported.

# %% [markdown]
# __Distribution of Cyber Attack Types | Pie Chart__

# %%
sunset_colors = ["#FF6F61","#DE5D83","#FFB347","#FFD700","#F08080","#CD5C5C","#FF8C00","#FF4500","#B22222","#8B0000"]
df['Attack Type'].value_counts().plot(kind='pie',figsize=(7,7), autopct='%1.1f%%', startangle=90,colors=sunset_colors)
plt.title('Most Common Attack types',fontsize=13, weight='bold')
plt.ylabel('')
plt.show()

# %% [markdown]
# - No single attack type dominates, showing that cyber threats are diverse and evenly distributed across techniques.
# - Phishing and DDoS lead slightly, while Man-in-the-Middle remains least frequent.
# - This uniform spread highlights that organizations face multiple forms of cyber risks simultaneously,
# reinforcing the need for multi-layered and adaptive cybersecurity strategies.

# %% [markdown]
# __Incident Frequency Across Target Industries | Horizontal Bar Plot__

# %%
muted_colors = ["#4E79A7","#A0CBE8","#F28E2B","#FFBE7D","#59A14F","#8CD17D","#B6992D","#F1CE63","#499894","#86BCB6"]
df['Target Industry'].value_counts().plot(kind='barh',figsize=(10,5),color=muted_colors)
plt.title('Incident Frequency Across Target Industries',fontsize=13, weight='bold')
plt.xlabel('Target Industry')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(True,linestyle='--')
plt.show()

# %% [markdown]
# - The analysis reveals that IT, Banking, and Healthcare sectors experience the highest frequency of cyber incidents, highlighting their vulnerability to attacks due to data sensitivity and financial exposure.
# - In contrast, Telecommunications and Government sectors exhibit comparatively lower incident counts, suggesting better preventive controls or underreporting in these domains.

# %% [markdown]
# __Variation in Incident Duration | KDE Plot__

# %%
df['Incident Resolution Time (in Hours)'].value_counts().plot(kind='kde',figsize=(10,5), color='darkcyan')
plt.title('Variation in Incident Duration',fontsize=13, weight='bold')
plt.xlabel('Incident Resolution Time (in Hours)')
plt.xticks(rotation=45)
plt.grid(True,linestyle='--')
plt.show()

# %% [markdown]
# - Most incidents were resolved in about 40 hours after detection, showing a consistent and balanced resolution pattern.
# - Very few incidents were fixed extremely quickly or took unusually long, which means response times are stable and there’s no major delay or inefficiency in the process.

# %% [markdown]
# __Incident Count Comparison | Bar Plot__

# %%
contrast_colors = ["#000000","#E6194B","#3CB44B","#FFE119","#4363D8","#F58231","#911EB4","#46F0F0","#F032E6","#BCF60C"]
df['Era'].value_counts().plot(kind='bar',figsize=(10,5),color=contrast_colors)
plt.title('Incident Count Comparison',fontsize=13, weight='bold')
plt.xlabel('Era')
plt.ylabel('Count')
plt.grid(True,linestyle='--')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - Cyber-attacks peaked before 2020 (Pre-Pandemic), marking the highest number of incidents across all eras.
#
# - During the Pandemic period (2020–2021), the count dropped drastically to less than half, possibly due to shifts in global operations and priorities.
#
# - The Recovery phase (2022–2023) shows a similar trend to the pandemic years, indicating a steady but not full rebound.
#
# - In the Recent period (2024–2025), incidents have further declined, reaching around 300, suggesting a period of relative stability or improved defense mechanisms.
#
#
# ---

# %% [markdown]
# ### **Bivariate Analysis:**
#
# > ***Purpose:*** *Explore relationships between pairs of variables.*

# %% [markdown]
# __High Loss Regions | Country & Financial Loss (in Million $) | Bar Plot__

# %%
forest_colors = ["#2E4600","#486B00","#A2C523","#7D4427","#B8B8B8","#5C821A","#98B06F","#4C3F54","#8C7051","#B0A990"]
sns.barplot(x='Country',y='Financial Loss (in Million $)',hue='Country',data=df,palette=forest_colors,errorbar=None)
plt.title('High Loss Regions',fontsize=13, weight='bold')
plt.xticks(rotation=45)
plt.grid(True,linestyle='--')
plt.show()

# %% [markdown]
# - Germany, the UK, and Australia recorded the highest financial losses, indicating greater exposure or higher-value targets in these regions.
# - In contrast, India, China, and France experienced comparatively lower losses, suggesting that their cyber defense systems or mitigation strategies may be more effective.

# %% [markdown]
# __User Exposure Across Industries | Number of Affected Users & Target Industry | Horizontal Bar Plot__

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df,x='Number of Affected Users',y='Target Industry', hue='Target Industry', palette='Set2') 
plt.title('User Exposure Across Industries',fontsize=13, weight='bold')
plt.ylabel('Target Industry')
plt.grid(True,which='major',linestyle='--')
plt.xlabel('Number of Affected Users')
plt.tight_layout()
plt.show()

# %% [markdown]
# - The IT and Education sectors show the highest number of affected users, possibly due to their heavy reliance on online systems and digital connectivity.
# - Interestingly, Retail and Telecommunications sectors show a lower number of impacted users, which is contrary to expectations, given the high online exposure of retail platforms.
#
# - This suggests that these industries may have implemented stronger user protection measures, or that breaches in these sectors tend to affect fewer users per incident.

# %% [markdown]
# __Attack Composition by Sector | Attack Type & Industry | % Stacked Bar Plot__

# %%
attack_industry = (pd.crosstab(df['Target Industry'].str.strip(),df['Attack Type'].str.strip(),normalize='index') * 100)

attack_industry = attack_industry.sort_index()

ax = attack_industry.plot(kind='bar', stacked=True, figsize=(10,6), colormap='tab20')
plt.title('Attack Composition by Sector', fontsize=13, weight='bold')
plt.ylabel('Composition (%)')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Attack Type', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Phishing, ransomware, and malware remain the leading threats overall.
# - Attack patterns vary by industry, showing no single dominant threat.
# - Data-heavy sectors like banking and healthcare face higher ransomware risk.
# - Government and telecom sectors are more prone to targeted, sophisticated attacks.
# - IT and retail industries attract web-based and credential-focused attacks.
# - Highlights the need for industry-specific cybersecurity strategies.

# %% [markdown]
# __Defense Effectiveness | Defense Mechanism Used & Incident Resolution Time (in Hours) | Violin Plot__

# %%
sns.violinplot(x='Defense Mechanism Used',y='Incident Resolution Time (in Hours)',data=df,color='mediumorchid')
plt.title('Defense Effectiveness',fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.grid(True,linestyle='--')
plt.show()

# %% [markdown]
# - Firewalls and AI-based detection systems demonstrate faster incident resolution, suggesting higher efficiency in identifying and mitigating threats early.
# - In contrast, VPNs, Encryption, and Antivirus tools show longer resolution times, which may indicate slower detection or higher complexity during response and recovery.
#
# - This highlights the importance of real-time monitoring and AI-driven tools for improving overall cyber defense responsiveness.
#
#
# ---

# %% [markdown]
# ### **Multivariate Analysis**
#
# >***Purpose:*** *Examine interactions among multiple variables to detect deeper patterns.*

# %% [markdown]
# __Evolution of User Impact Across Industries | Year, Target Industry & Number of Affected Users | Heatmap__

# %%
impact_table = df.groupby(['Year', 'Target Industry'])['Number of Affected Users'].sum().reset_index()

impact_pivot = impact_table.pivot(index='Target Industry', columns='Year', values='Number of Affected Users')

plt.figure(figsize=(14,8))
sns.heatmap(impact_pivot,cmap='YlOrRd',linewidths=0.5,linecolor='white',annot=True,fmt='.0f')

plt.title('Evolution of User Impact Across Industries', fontsize=14, fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Target Industry')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ___How to read this heatmap:___
#
# Each row → a specific industry (e.g., Banking, Healthcare, Energy).
#
# Each column → a year.
#
# Color intensity → the total number of affected users.
#
# 🔸 Lighter color → fewer users impacted.
#
# 🔴 Darker color → more users impacted.
#
# So, dark red cells point to years and industries with major user impact.
#
#
# Interpretation:
#
# - The heatmap reveals that IT and Education sectors consistently suffered the highest user impact, peaking in 2017 and 2018 respectively.
# - Banking and Healthcare maintained steady vulnerability, reflecting their critical role in data-driven operations.
# - Noticeable spikes around 2020–2021 across industries align with the global increase in cyber activity during the pandemic, highlighting the strain on digital infrastructures.
# - Overall, the data underscores the need for sector-specific, adaptive cybersecurity strategies to manage evolving user risks.

# %% [markdown]
# __Relationship Between Attack Types and Security Vulnerabilities | Attack Type & Security Vulnerability Type | Grouped Bar Plot__

# %%
attack_bar = (df.groupby(['Attack Type', 'Security Vulnerability Type']).size().reset_index(name='Incident Count'))

plt.figure(figsize=(14,6))
sns.barplot(data=attack_bar,x='Attack Type',y='Incident Count',hue='Security Vulnerability Type')
plt.title('Relationship Between Attack Types and Security Vulnerabilities',fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.ylabel('Incident Count')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Human factors (Social Engineering, Weak Passwords) remain major contributors to most attack types.
#
# - Technical vulnerabilities (Unpatched Software, Zero-days) continue to pose serious risks, especially in Malware, Phishing, and SQL Injection.
#
# - The data reflects the need for a dual security approach:
#   - Strengthening human awareness and credential practices
#   - Ensuring timely patching and vulnerability management

# %% [markdown]
# __Comparison of Cyber Threats Before and After the Pandemic | Year & Attack Type | Side-by-side Bars__

# %%
df['Pandemic Period'] = df['Year'].apply(lambda x: 'Pre-Pandemic' if x < 2020 else 'Post-Pandemic')

attack_period = (df.groupby(['Attack Type', 'Pandemic Period']).size().reset_index(name='Incident Count'))


plt.figure(figsize=(14,7))
sns.barplot(data=attack_period,x='Attack Type',y='Incident Count',hue='Pandemic Period',hue_order=['Pre-Pandemic', 'Post-Pandemic'],palette='Set2')

plt.title('Comparison of Cyber Threats Before and After the Pandemic', fontsize=14, fontweight='bold')
plt.xlabel('Attack Type')
plt.ylabel('Number of Incidents')
plt.xticks(rotation=45)
plt.legend(title='Pandemic Period', loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# - The comparison between pre-pandemic and post-pandemic periods shows that most attack types such as DDoS, Malware, Phishing, and Man-in-the-Middle maintained similar incident frequencies across both eras.
#
# - However, Ransomware and SQL Injection display a notable rise in incidents post-pandemic, indicating a shift in attacker focus toward data exfiltration and exploitation of web vulnerabilities during the remote work era.
#
# - This pattern highlights how cybercriminals adapted to the changing digital environment, leveraging increased online dependency and exposed endpoints after 2020.

# %% [markdown]
# __Global Overview of Attack Sources Across Industries | Attack Source, Industry & Country  | Bubble Plot__

# %%
agg = (df.groupby(['Country', 'Target Industry', 'Attack Source']).size().reset_index(name='incidents'))

n_countries = 6
top_countries = (agg.groupby('Country')['incidents'].sum().nlargest(n_countries).index)
agg_sub = agg[agg['Country'].isin(top_countries)].copy()

agg_sub['Attack Source'] = agg_sub['Attack Source'].astype(str)
agg_sub['Target Industry'] = agg_sub['Target Industry'].astype(str)

g = sns.relplot(data=agg_sub,x='Attack Source',y='Target Industry',size='incidents',sizes=(50, 2000),hue='incidents',palette='viridis',
    col='Country',col_wrap=3,alpha=0.7,edgecolor='k',linewidth=0.3,kind='scatter',height=4,aspect=1.2,)

for ax in g.axes.flatten():
    ax.tick_params(axis='x', rotation=45, labelsize=9)
    ax.set_xlabel('')
    ax.set_ylabel('')

g.set_axis_labels("Attack Source", "Target Industry")
g.fig.suptitle('Global Overview of Attack Sources Across Industries (Bubble Size = Incidents)', y=1.03, fontsize=14, fontweight='bold')
plt.tight_layout()
plt.legend(title='Incidents', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\sreel\AppData\Local\Temp\ipykernel_9800\1445407404.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Incidents', bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# - Global Attackers: Nation-state and hacker groups dominate, showing political or financial motives.
#
# - Vulnerable Sectors: Healthcare and Government face the highest attack volumes.
#
# - Attribution Gap: Many incidents remain “Unknown,” highlighting traceability challenges.
#
# - Regional Differences:
#     - Developed nations (UK, Japan, France) → more nation-state attacks.
#
#     - Emerging ones (India, Brazil) → mixed attack sources.
#
#
# ---

# %% [markdown]
# ## **Correlation and Statistical Analysis**
#
# > ***Purpose:*** *Quantify relationships between numeric features.*

# %% [markdown]
# __Correlation Between Financial Loss, Affected Users, and Resolution Time | Correlation matrix__

# %%
numeric_cols = ['Financial Loss (in Million $)','Number of Affected Users','Incident Resolution Time (in Hours)']
corr = df[numeric_cols].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True,cmap='RdYlBu',center=0,linewidths=0.5)
plt.title('Correlation Between Financial Loss, Affected Users, and Resolution Time', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# -  No strong correlations exist among financial and operational metrics here.
#
# - Financial losses are independent of both the number of affected users and resolution time, suggesting other hidden drivers (e.g., attack severity, organization size).
#
# - Operational efficiency (resolution speed) doesn’t seem to predict financial or user impact. It might depend on incident complexity or defense maturity.
#
#
# ---

# %% [markdown]
# ## **9. Temporal and Trend Analysis**
#
# > ***Purpose:*** *Understand how threats and defenses have evolved from 2015 to 2024.*

# %% [markdown]
# __Evolution of Attack Landscape | Year & Attack Type | 100% Stacked Area Chart__

# %%
attack_trend = df.groupby(["Year", "Attack Type"]).size().unstack(fill_value=0)

attack_percent = attack_trend.div(attack_trend.sum(axis=1), axis=0) * 100

attack_percent.plot.area(figsize=(10, 6), alpha=0.8)

plt.title("Evolution of Attack Landscape: Year & Attack Type", fontsize=14, fontweight='bold')
plt.xlabel("Year")
plt.ylabel("Percentage Share (%)")
plt.legend(title="Attack Type", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Between 2015 and 2024, the global attack landscape remained diverse and dynamic, with no single technique dominating consistently.
# - Phishing and Ransomware emerged as enduring threats, while Malware and DDoS maintained stable shares.
# - This stability reflects both attacker adaptability and improved multi-layered defense strategies.

# %% [markdown]
# __Defense Mechanism Effectiveness Over Time | Year & Avg Financial Loss (by Defense Mechanism) | Multi-series Line Chart__

# %%
loss_trend = (df.groupby(["Year", "Defense Mechanism Used"])["Financial Loss (in Million $)"].mean().unstack())

loss_trend.plot(figsize=(10, 6), marker='o')

plt.title("Average Financial Loss by Defense Mechanism Over Time", fontsize=14, fontweight='bold')
plt.xlabel("Year")
plt.ylabel("Avg Financial Loss (Million $)")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title="Defense Mechanism", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Between 2015 and 2024, average financial losses per defense mechanism remained relatively stable, indicating that cyber defenses have matured but not dramatically improved efficiency.
# - Encryption and modern AI-based detection show gradual improvement, while traditional defenses (firewall, antivirus) show stagnation.
# - Post-2020 volatility aligns with pandemic-related shifts in network security patterns (VPN reliance, remote access).

# %% [markdown]
# __Global Cyber Impact Over Time | Financial Loss & Users | Dual-axis Line__

# %%
plt.figure(figsize=(10,5))
yearly = df.groupby('Year')[['Financial Loss (in Million $)', 'Number of Affected Users']].sum().reset_index()

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.plot(yearly['Year'], yearly['Number of Affected Users'], 'o-', color='orange', label='Affected Users')
ax2.plot(yearly['Year'], yearly['Financial Loss (in Million $)'], 's-', color='blue', label='Financial Loss (M$)')

ax1.set_xlabel('Year')
ax1.set_ylabel('Affected Users')
ax2.set_ylabel('Financial Loss (Million $)')
ax1.set_title('Yearly Trend: Financial Loss & Affected Users (2015–2024)')

plt.axvline(2020, color='gray', ls='--', lw=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Cyber incidents surged dramatically post-2020, peaking around 2021–2022, before stabilizing.
# - This reflects a shift from pandemic-induced cyber chaos to a more controlled cybersecurity landscape, though risks remain significant.
#
#
# ---

# %% [markdown]
# ## **10. Insight Extraction and Interpretation**
#
# > ***Purpose:*** *Translate findings into actionable conclusions.*
#
# __Summary:__ How the Analysis Answers the Key Linked Questions
#
# | **Linked Question**                                               | **Addressed In**                     | **Key Findings**                                                                                                                                                                   |
# | ----------------------------------------------------------------- | ------------------------------------ | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **1. High-risk countries and industries over time**               | *Univariate & Bivariate Analysis*    | The UK, Brazil, Japan, and France report the highest incidents. IT, Banking, and Healthcare remain the most vulnerable industries due to data sensitivity and financial exposure. |
# | **2. Attack types & vulnerabilities driving highest losses**      | *Bivariate & Multivariate Analysis*  | Phishing, Ransomware, and DDoS dominate globally. Human errors (social engineering, weak passwords) and unpatched software are the main exploited vulnerabilities.                |
# | **3. Incidents with high individual severity**                    | *Correlation & Statistical Analysis* | Weak correlations between loss, user impact, and resolution time indicate that severity is driven more by the complexity of attacks and the value of targeted assets than by the size of the incident.          |
# | **4. Defense strategies that reduce loss & time**                 | *Bivariate & Temporal Analysis*      | AI-based detection and firewalls resolve incidents faster, while VPNs and traditional tools show longer resolution times. AI-driven defenses have improved post-2020.             |
# | **5. Temporal shifts in threats post-2020**                       | *Temporal & Multivariate Analysis*   | Post-pandemic years saw spikes in Ransomware and SQL Injection, followed by stabilization after 2022, signaling improved defensive adaptation.                                   |
# | **6. Relationship between operational delays & financial damage** | *Correlation Analysis*               | Minimal correlation observed; faster resolution does not always reduce losses, suggesting that incident complexity and organizational preparedness play a larger role.            |
#
# __Summary Insight:__
# - From 2015 to 2024, the global cybersecurity landscape has remained diverse and adaptive.
# - High-risk countries include the UK, Brazil, Japan, and France, with IT, Banking, and Healthcare being most targeted.
# - Phishing, Ransomware, and DDoS dominate attack types, while human error and unpatched systems remain critical vulnerabilities.
# - AI-driven defenses now outperform traditional tools, achieving faster resolution with reduced losses.
# - Post-2020, incidents surged in complexity but stabilized by 2024, indicating improved resilience.
# - However, financial losses show weak correlation with resolution time, suggesting that the true drivers of cost are attack sophistication and target value rather than operational speed.
#
# The study reveals that global cyber risks have evolved dynamically across geography, industry, and time.
# AI-driven defense systems and adaptive cybersecurity measures have begun stabilizing incident severity post-2020, though complexity-driven losses remain a major concern.
#
# ---

# %% [markdown]
# ## **11. Limitations & Future Scope**
# > ***Purpose:*** *Acknowledging current analytical boundaries and highlighting directions for future enhancement.*
#
# ### **Limitations**
# - The dataset may not capture all global incidents, leading to regional or reporting bias.
# - Severity metrics (financial loss, user impact) depend on available data; some values might be estimated or incomplete.
# - Analysis assumes consistent reporting standards across countries and industries, which may not hold true in practice.
# - Temporal trends (especially around 2020–2021) could be affected by underreporting during the pandemic.
# - Defense effectiveness is evaluated from incident outcomes only, not from proactive prevention data, which limits insight into early threat mitigation.
#
#
#
# ### **Future Scope**
# - Integrate real-time cybersecurity feeds or threat intelligence APIs to enhance trend accuracy.
# - Extend analysis to include economic and organizational attributes (e.g., company size, sector investment in security).
# - Apply machine learning models for predictive insights. e.g., forecasting financial loss or user impact from historical data.
# - Use network graph analysis to visualize global attack connections and propagation patterns.
# - Continuously update the dashboard to monitor emerging threats (e.g., AI-based or quantum attacks) in near real-time.
